# %%
import pandas as pd
import seaborn as sns

# %%
ce_data = pd.read_csv("../data/calories.csv")

# %%
ce_data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68  190.00   94.00     29.00      105.00      40.80
# 1  14861698  female   20  166.00   60.00     14.00       94.00      40.30
# 2  11179863    male   69  179.00   79.00      5.00       88.00      38.70
# 3  16180408  female   34  179.00   71.00     13.00      100.00      40.50
# 4  17771927  female   27  154.00   58.00     10.00       81.00      39.80
#
#    Calories
# 0    231.00
# 1     66.00
# 2     26.00
# 3     71.00
# 4     35.00

# %%
pd.set_option("display.float_format", lambda x: "%.2f" % x)

# %%
ce_data.describe()
# Out:
#           User_ID      Age   Height   Weight  Duration  Heart_Rate  Body_Temp  \
# count    15000.00 15000.00 15000.00 15000.00  15000.00    15000.00   15000.00
# mean  14977358.54    42.79   174.47    74.97     15.53       95.52      40.03
# std    2872851.45    16.98    14.26    15.04      8.32        9.58       0.78
# min   10001159.00    20.00   123.00    36.00      1.00       67.00      37.10
# 25%   12474190.75    28.00   164.00    63.00      8.00       88.00      39.60
# 50%   14997285.00    39.00   175.00    74.00     16.00       96.00      40.20
# 75%   17449278.75    56.00   185.00    87.00     23.00      103.00      40.60
# max   19999647.00    79.00   222.00   132.00     30.00      128.00      41.50
#
#        Calories
# count  15000.00
# mean      89.54
# std       62.46
# min        1.00
# 25%       35.00
# 50%       79.00
# 75%      138.00
# max      314.00

# %% [markdown]
# ## Variable distributions

# %%
_ = sns.countplot(x = "Gender", data = ce_data)

# %%
ce_data["Gender"].value_counts()
# Out:
# Gender
# female    7553
# male      7447
# Name: count, dtype: int64

# %%
_ = sns.histplot(x = "Age", data = ce_data, bins = 30)

# %%
_ = sns.histplot(x = "Height", data = ce_data, bins = 30)

# %%
_ = sns.histplot(x = "Weight", data = ce_data, bins = 25)

# %%
_ = sns.histplot(x = "Duration", data = ce_data, bins = 10)

# %%
_ = sns.histplot(x = "Heart_Rate", data = ce_data, bins = 30)

# %%
_ = sns.histplot(x = "Body_Temp", data = ce_data)

# %% [markdown]
# Unexpected gaps in the chart, let's try with different bins.

# %%
_ = sns.histplot(x = "Body_Temp", data = ce_data, bins = 40)

# %%
_ = sns.histplot(x = "Calories", data = ce_data, bins = 30)
